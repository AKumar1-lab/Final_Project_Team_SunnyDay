# %%
import pandas as pd
zips=pd.read_csv('more_zips_ghi.csv')

# %%
zips=zips.drop(["Unnamed: 0"],axis=1)
zips=zips.loc[zips['state']!='AE']
zips=zips.loc[zips['state']!='AP']
zips=zips.loc[zips['state']!='SD']
zips=zips.loc[zips['state']!='MP']
zips=zips.loc[zips['state']!='FM']
zips=zips.loc[zips['state']!='DC']
zips=zips.loc[zips['state']!='AK']
zips=zips.loc[zips['state']!='HI']
zips=zips.loc[zips['state']!='AA']
zips=zips.loc[zips['state']!='PR']
zips=zips.loc[zips['state']!='VI']
zips=zips.loc[zips['state']!='GU']
zips=zips.loc[zips['state']!='AS']
zips=zips.loc[zips['state']!='MH']
zips=zips.loc[zips['state']!='PW']
zips
# Out:
#          zip      type  decommissioned primary_city acceptable_cities  \
# 0        501    UNIQUE               0   Holtsville               NaN
# 1        544    UNIQUE               0   Holtsville               NaN
# 194     1001  STANDARD               0       Agawam               NaN
# 195     1002  STANDARD               0      Amherst   Cushman, Pelham
# 196     1003  STANDARD               0      Amherst               NaN
# ...      ...       ...             ...          ...               ...
# 42445  99363    PO BOX               0      Wallula               NaN
# 42446  99371  STANDARD               0    Washtucna               NaN
# 42447  99401  STANDARD               0      Anatone               NaN
# 42448  99402  STANDARD               0       Asotin               NaN
# 42449  99403  STANDARD               0    Clarkston               NaN
#
#             unacceptable_cities state              county  \
# 0      Internal Revenue Service    NY      Suffolk County
# ...

# %%
zips.to_csv('cleaned_zips.csv')

# %%
pv=pd.read_csv('pv_open_2020.csv')
pv
# Out:
#        sc_gid  capacity_factor  global_horizontal_irradiance  capacity_mw  \
# 0           0         0.139177                      3.354821   591.452887
# 1           1         0.137451                      3.306946   596.647266
# 2           2         0.136000                      3.293000     2.851200
# 3           3         0.141827                      3.417382  2014.383178
# 4           4         0.137829                      3.327924  3557.400778
# ...       ...              ...                           ...          ...
# 55514   55530         0.206913                      5.196184   965.520000
# 55515   55531         0.205765                      5.174338   238.679140
# 55516   55532         0.208000                      5.208001    25.093151
# 55517   55533         0.207652                      5.203368   330.091200
# 55518   55534         0.208623                      5.229781   792.078877
#
#        area_sq_km  latitude  longitude  distance_to_transmission_km
# ...

# %%
missing=zips.loc[zips['ghi']=='none']
missing
# Out:
#          zip      type  decommissioned    primary_city acceptable_cities  \
# 541     1907  STANDARD               0      Swampscott               NaN
# 612     2108  STANDARD               0          Boston               NaN
# 613     2109  STANDARD               0          Boston               NaN
# 614     2110  STANDARD               0          Boston               NaN
# 615     2111  STANDARD               0          Boston               NaN
# ...      ...       ...             ...             ...               ...
# 42216  98826  STANDARD               0     Leavenworth               NaN
# 42238  98852    PO BOX               0        Stehekin               NaN
# 42260  98929  STANDARD               1          Naches     Goose Prairie
# 42346  99139  STANDARD               0            Ione               NaN
# 42358  99153  STANDARD               0  Metaline Falls      Metaline Fls
#
#                                      unacceptable_cities state  \
# ...

# %%
for i in range(len(missing)):
    value=pv.loc[(pv['latitude']>=missing['latitude'].iloc[i]-.2)&(pv['latitude']<=missing['latitude'].iloc[i]+.2)&(pv['longitude']>=missing['longitude'].iloc[i]-.2)&(pv['longitude']<=missing['longitude'].iloc[i]+.2)]['global_horizontal_irradiance'].mean()
    missing['ghi'].iloc[i]=value
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
missing=missing.fillna('none')
missing
# Out:
#          zip      type  decommissioned    primary_city acceptable_cities  \
# 541     1907  STANDARD               0      Swampscott              none
# 612     2108  STANDARD               0          Boston              none
# 613     2109  STANDARD               0          Boston              none
# 614     2110  STANDARD               0          Boston              none
# 615     2111  STANDARD               0          Boston              none
# ...      ...       ...             ...             ...               ...
# 42216  98826  STANDARD               0     Leavenworth              none
# 42238  98852    PO BOX               0        Stehekin              none
# 42260  98929  STANDARD               1          Naches     Goose Prairie
# 42346  99139  STANDARD               0            Ione              none
# 42358  99153  STANDARD               0  Metaline Falls      Metaline Fls
#
#                                      unacceptable_cities state  \
# ...

# %%
ghi=pd.DataFrame(missing[['zip','ghi']])
ghi
# Out:
#          zip       ghi
# 541     1907  4.019472
# 612     2108  4.017692
# 613     2109  4.020341
# 614     2110  4.020341
# 615     2111  4.017692
# ...      ...       ...
# 42216  98826  4.062744
# 42238  98852      none
# 42260  98929  4.155096
# 42346  99139  3.555075
# 42358  99153  3.532156
#
# [1300 rows x 2 columns]

# %%
ghi.to_csv('new_values.csv')
