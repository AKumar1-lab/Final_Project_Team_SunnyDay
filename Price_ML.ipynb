# %%
#For colab only
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
avg_price_df = pd.read_csv('gdrive/My Drive/Resources/avgprice_annual.csv')
avg_price_df
# Out:
#       Year State Industry Sector Category  ...  Transportation Other  Total
# 0     2020    AK  Total Electric Industry  ...            0.00   NaN  19.82
# 1     2020    AL  Total Electric Industry  ...            0.00   NaN   9.84
# 2     2020    AR  Total Electric Industry  ...           13.32   NaN   8.32
# 3     2020    AZ  Total Electric Industry  ...            9.38   NaN  10.44
# 4     2020    CA  Total Electric Industry  ...           10.07   NaN  18.00
# ...    ...   ...                      ...  ...             ...   ...    ...
# 4600  1990    WA   Full-Service Providers  ...             NaN  3.13   3.40
# 4601  1990    WI   Full-Service Providers  ...             NaN  6.47   5.37
# 4602  1990    WV   Full-Service Providers  ...             NaN  8.19   4.73
# 4603  1990    WY   Full-Service Providers  ...             NaN  7.90   4.21
# 4604  1990    US   Full-Service Providers  ...             NaN  6.40   6.57
#
# [4605 rows x 9 columns]

# %%
avg_price_df["Industry Sector Category"].value_counts()
# Out:
# Total Electric Industry                  1612
# Full-Service Providers                   1612
# Restructured Retail Service Providers     476
# Energy-Only Providers                     474
# Delivery-Only Service                     431
# Name: Industry Sector Category, dtype: int64

# %%
ElecRates_df = pd.DataFrame(avg_price_df[avg_price_df["Industry Sector Category"] =="Total Electric Industry"].value_counts()).reset_index()

# %%
ElecRates_df.value_counts()
# Out:
# Series([], dtype: int64)

# %%
ElecRates_df.head()
# Out:
# Empty DataFrame
# Columns: [Year, State, Industry Sector Category, Residential, Commercial, Industrial, Transportation, Other, Total, 0]
# Index: []

# %%
avg_price_df.drop(['Commercial','Industrial','Transportation','Other','Total','Industry Sector Category'],axis=1)
# Out:
#       Year State  Residential
# 0     2020    AK        22.57
# 1     2020    AL        12.58
# 2     2020    AR        10.41
# 3     2020    AZ        12.27
# 4     2020    CA        20.45
# ...    ...   ...          ...
# 4600  1990    WA         4.39
# 4601  1990    WI         6.63
# 4602  1990    WV         5.90
# 4603  1990    WY         5.97
# 4604  1990    US         7.83
#
# [4605 rows x 3 columns]

# %%
avg_price_df["State"].value_counts()
# Out:
# US    133
# WA    131
# NH    131
# NY    131
# RI    131
# PA    131
# IL    131
# CA    131
# MA    129
# MT    129
# NJ    127
# OH    127
# DE    127
# MI    127
# MD    125
# ME    125
# DC    122
# CT    122
# OR    119
# NV    112
# VA    110
# ID     79
# MO     68
# NM     66
# TX     65
# AZ     64
# OK     62
# MN     62
# WV     62
# IA     62
# LA     62
# WY     62
# KS     62
# ND     62
# TN     62
# CO     62
# MS     62
# UT     62
# AR     62
# NE     62
# IN     62
# AL     62
# FL     62
# WI     62
# SC     62
# NC     62
# VT     62
# SD     62
# KY     62
# HI     62
# AK     62
# GA     62
# Name: State, dtype: int64

# %%
avg_price_df["Year"].value_counts()
# Out:
# 2008    170
# 2009    170
# 2004    168
# 2019    167
# 2010    167
# 2020    167
# 2005    167
# 2017    167
# 2015    167
# 2006    167
# 2016    167
# 2014    167
# 2018    167
# 2007    167
# 2012    164
# 2013    164
# 2001    164
# 2011    164
# 2003    161
# 2002    161
# 2000    156
# 1999    140
# 1998    128
# 1997    128
# 1996    106
# 1990    104
# 1993    104
# 1994    104
# 1991    104
# 1995    104
# 1992    104
# Name: Year, dtype: int64

# %%
import plotly.express as px

fig = px.bar(avg_price_df, x='State', y='Year')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9db83e85-58c0-4991-94c9-ba22e13e5743" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9db83e85-58c0-4991-94c9-ba22e13e5743")) {
#                     Plotly.newPlot(
#                         '9db83e85-58c0-4991-94c9-ba22e13e5743',
# ...

# %%
import plotly.express as px

fig = px.bar(avg_price_df, x='State', y='Residential')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="52083b68-4464-4b99-89bb-be98d7ddf6e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("52083b68-4464-4b99-89bb-be98d7ddf6e6")) {
#                     Plotly.newPlot(
#                         '52083b68-4464-4b99-89bb-be98d7ddf6e6',
# ...
